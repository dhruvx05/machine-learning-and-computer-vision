# %%
from sklearn.datasets import load_diabetes
import pandas as pd

data = load_diabetes(as_frame=True)
df = data.frame

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
X = df[['bmi']]
y = df['target']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

# %%
#mse and R2(Square) value

mse = mean_squared_error(y,y_pred)
print("Mean Squared Error (MSE):", mse)

r2= r2_score(y,y_pred)
print("R2 value:", r2)
# Out:
# Mean Squared Error (MSE): 3890.456585461273
# R2 value: 0.3439237602253802

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

X = df[['bmi']]
y = df['target']

model = LinearRegression()
model.fit(X,y)

y_pred = model.predict(X)

# %%
# data visualization
plt.scatter(X, y)
plt.xlabel("BMI")
plt.ylabel("Target")
plt.title("Linear Regression")
plt.show()

# %%
import numpy as np

#Sorting for clean straight line
X_sorted = np.sort(X.values, axis=0)
y_fit = model.predict(X_sorted)


plt.scatter(X, y)
plt.plot(X_sorted, y_fit, color = "red")
plt.xlabel("BMI")
plt.ylabel("Target")
plt.title("Linear Regression Curve Fitting")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
